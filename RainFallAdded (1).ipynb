# %%
# Supress Warnings
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Base_polpop_iell_cs=pd.read_csv('C:\MS\EDA\Base_polpop_iell_carsales_15oct.csv')

# %%
Base_polpop_iell_cs.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'City_Town_Village_Area',
#        'Type_of_Location', 'TS', 'year_number', 'month_number', 'NO2_Median',
#        'RSPM_PM10_Median', 'SO2_Median', 'SPM_Median', 'Median_SO2_MOM_diff',
#        'Median_NO2_MOM_diff', 'Median_RSPM_PM10_MOM_diff',
#        'Median_SPM_MOM_diff', 'NO2_P10', 'RSPM_PM10_P10', 'SO2_P10', 'SPM_P10',
#        'P10_NO2_MOM_diff', 'P10_SO2_MOM_diff', 'P10_RSPM_PM10_MOM_diff',
#        'P10_SPM_MOM_diff', 'NO2_P90', 'RSPM_PM10_P90', 'SO2_P90', 'SPM_P90',
#        'month_number_diff', 'P90_NO2_MOM_diff', 'P90_SO2_MOM_diff',
#        'P90_RSPM_PM10_MOM_diff', 'P90_SPM_MOM_diff', 'year_number_diff',
#        'NO2_Median_YOY_diff', 'SO2_Median_YOY_diff',
#        'RSPM_PM10_Median_YOY_diff', 'SPM_Median_YOY_diff', 'NO2_P10_YOY_diff',
#        'SO2_P10_YOY_diff', 'RSPM_PM10_P10_YOY_diff', 'SPM_P10_YOY_diff',
#        'NO2_P90_YOY_diff', 'SO2_P90_YOY_diff', 'RSPM_PM10_P90_YOY_diff',
# ...

# %%
Base_polpop_iell_cs.City_Town_Village_Area.unique()
# Out:
# array(['AKOLA', 'AMRAVATI', 'AURANGABAD', 'BADLAPUR', 'CHANDRAPUR',
#        'DOMBIVLI', 'GREATER MUMBAI', 'JALGAON', 'JALNA', 'KOLHAPUR',
#        'LATUR', 'LOTE', 'MAHAD', 'MUMBAI', 'NAGPUR', 'NANDED', 'NASHIK',
#        'NAVI MUMBAI', 'PUNE', 'ROHA', 'SANGLI', 'SOLAPUR', 'TARAPUR',
#        'THANE', 'ULHASNAGAR'], dtype=object)

# %%
Base_polpop_iell_cs.describe()
# Out:
#         Unnamed: 0  Unnamed: 0.1            TS  year_number  month_number  \
# count  5715.000000   5715.000000  5.715000e+03  5715.000000   5715.000000
# mean   2857.000000   2857.000000  2.006737e+07  2006.730534      6.480315
# std    1649.922725   1649.922725  6.764000e+04     6.763946      3.462195
# min       0.000000      0.000000  1.987001e+07  1987.000000      1.000000
# 25%    1428.500000   1428.500000  2.001012e+07  2001.000000      3.000000
# 50%    2857.000000   2857.000000  2.009002e+07  2009.000000      6.000000
# 75%    4285.500000   4285.500000  2.012009e+07  2012.000000      9.000000
# max    5714.000000   5714.000000  2.015012e+07  2015.000000     12.000000
#
#         NO2_Median  RSPM_PM10_Median   SO2_Median   SPM_Median  \
# count  5677.000000       3977.000000  5677.000000  2990.000000
# mean     31.398418         96.220010    18.348264   194.025124
# std      16.299930         40.257804    12.528923    91.949094
# ...

# %%
Base_rainfall=pd.read_csv("C:\\MS\\EDA\\rainfallmh.csv")

# %%
Base_rainfall.columns
# Out:
# Index(['District', 'Year', 'January', 'February', 'March', 'April', 'May',
#        'June', 'July', 'August', 'September', 'October', 'November',
#        'December', 'Annual Total'],
#       dtype='object')

# %%
Base_rainfall.tail(n=10)
# Out:
#      District  Year  January  February  March  April   May   June   July  \
# 221    Washim  2008      0.0       0.0    9.5    0.0   0.0  136.4  161.0
# 222    Washim  2009      0.0       0.0    5.0    0.0  11.6   75.1  171.9
# 223    Washim  2010     19.1       6.0   31.1    0.0   5.0  197.0  486.4
# 224   Yeotmal  2004     36.7       0.0    0.0    0.0  69.0  139.6  233.1
# 225   Yeotmal  2005     81.8      14.0   18.8   11.0  13.8  164.8  488.1
# 226   Yeotmal  2006      0.0       0.0   57.6   14.0  27.9  112.0  351.7
# 227   Yeotmal  2007      0.0       0.0    4.6    1.0  14.4  122.0  250.4
# 228   Yeotmal  2008      0.0       0.0   72.4    7.2   5.2   83.4  178.1
# 229   Yeotmal  2009      0.0       0.0    1.2    0.0  10.2   99.4  142.3
# 230   Yeotmal  2010     25.3      15.0   10.3    0.0   0.0  120.7  391.8
#
#      August  September  October  November  December  Annual Total
# 221   110.3      209.7     38.1       0.0       5.2         670.2
# ...

# %%
Base_rainfall_expanded=pd.melt(Base_rainfall, id_vars=['District', 'Year'], value_vars=['January', 'February', 'March', 'April', 'May','June', 'July', 'August', 'September', 'October', 'November','December', 'Annual Total'])

# %%
Base_rainfall_expanded
# Out:
#          District  Year      variable   value
# 0      Ahmednagar  2004       January     0.0
# 1      Ahmednagar  2005       January     0.8
# 2      Ahmednagar  2006       January     0.0
# 3      Ahmednagar  2007       January     0.0
# 4      Ahmednagar  2008       January     0.0
# 5      Ahmednagar  2009       January     0.0
# 6      Ahmednagar  2010       January     0.0
# 7           Akola  2004       January    15.8
# 8           Akola  2005       January    35.5
# 9           Akola  2006       January     0.0
# 10          Akola  2007       January     0.0
# 11          Akola  2008       January    14.3
# 12          Akola  2009       January     0.0
# 13          Akola  2010       January    29.6
# 14       AMRAVATI  2004       January    18.7
# 15       AMRAVATI  2005       January    10.7
# 16       AMRAVATI  2006       January     0.0
# 17       AMRAVATI  2007       January     0.0
# 18       AMRAVATI  2008       January     0.0
# ...

# %%
Base_rainfall_expanded.columns=['District', 'Year', 'month', 'rainfall']

# %%
Base_rainfall_expanded

# %%
import calendar

# %%
convt={v: k for k,v in enumerate(calendar.month_name)}

# %%
convt['Annual Total'] = convt.pop('')

# %%
convt
# Out:
# {'January': 1,
#  'February': 2,
#  'March': 3,
#  'April': 4,
#  'May': 5,
#  'June': 6,
#  'July': 7,
#  'August': 8,
#  'September': 9,
#  'October': 10,
#  'November': 11,
#  'December': 12,
#  'Annual Total': 0}

# %%
Base_rainfall_expanded.month=Base_rainfall_expanded.month.map(convt)

# %%
Base_rainfall_expanded.head(n=10)
# Out:
#      District  Year  month  rainfall
# 0  Ahmednagar  2004      1       0.0
# 1  Ahmednagar  2005      1       0.8
# 2  Ahmednagar  2006      1       0.0
# 3  Ahmednagar  2007      1       0.0
# 4  Ahmednagar  2008      1       0.0
# 5  Ahmednagar  2009      1       0.0
# 6  Ahmednagar  2010      1       0.0
# 7       Akola  2004      1      15.8
# 8       Akola  2005      1      35.5
# 9       Akola  2006      1       0.0

# %%
Base_rainfall_expanded.District=Base_rainfall_expanded.District.str.upper()

# %%
Base_rainfall_expanded.District=Base_rainfall_expanded.District.str.strip()

# %%
NameCorrection={'NASIK':'NASHIK','SHOLAPUR':'SOLAPUR'}

# %%
Base_rainfall_expanded.loc[Base_rainfall_expanded.District == 'NASIK','District']='NASHIK'

# %%
Base_rainfall_expanded.loc[Base_rainfall_expanded.District == 'SHOLAPUR','District']='SOLAPUR'

# %%
Base_rainfall_expanded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3003 entries, 0 to 3002
# Data columns (total 4 columns):
# District    3003 non-null object
# Year        3003 non-null int64
# month       3003 non-null int64
# rainfall    3003 non-null float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 93.9+ KB

# %%
Base_polpop_iell_rf=Base_polpop_iell_cs.merge(Base_rainfall_expanded,how='outer', suffixes=('_ppiellsc', '_rainfall'),left_on=['City_Town_Village_Area','year_number','month_number'], right_on=['District','Year','month'])

# %%
Base_polpop_iell_rf.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'City_Town_Village_Area',
#        'Type_of_Location', 'TS', 'year_number', 'month_number', 'NO2_Median',
#        'RSPM_PM10_Median', 'SO2_Median', 'SPM_Median', 'Median_SO2_MOM_diff',
#        'Median_NO2_MOM_diff', 'Median_RSPM_PM10_MOM_diff',
#        'Median_SPM_MOM_diff', 'NO2_P10', 'RSPM_PM10_P10', 'SO2_P10', 'SPM_P10',
#        'P10_NO2_MOM_diff', 'P10_SO2_MOM_diff', 'P10_RSPM_PM10_MOM_diff',
#        'P10_SPM_MOM_diff', 'NO2_P90', 'RSPM_PM10_P90', 'SO2_P90', 'SPM_P90',
#        'month_number_diff', 'P90_NO2_MOM_diff', 'P90_SO2_MOM_diff',
#        'P90_RSPM_PM10_MOM_diff', 'P90_SPM_MOM_diff', 'year_number_diff',
#        'NO2_Median_YOY_diff', 'SO2_Median_YOY_diff',
#        'RSPM_PM10_Median_YOY_diff', 'SPM_Median_YOY_diff', 'NO2_P10_YOY_diff',
#        'SO2_P10_YOY_diff', 'RSPM_PM10_P10_YOY_diff', 'SPM_P10_YOY_diff',
#        'NO2_P90_YOY_diff', 'SO2_P90_YOY_diff', 'RSPM_PM10_P90_YOY_diff',
# ...

# %%
Base_polpop_iell_rf.loc[Base_polpop_iell_rf.City_Town_Village_Area.isnull(),['District', 'Year_rainfall', 'month', 'rainfall']]
# Out:
#         District  Year_rainfall  month  rainfall
# 5715  AHMEDNAGAR         2004.0    1.0       0.0
# 5716  AHMEDNAGAR         2005.0    1.0       0.8
# 5717  AHMEDNAGAR         2006.0    1.0       0.0
# 5718  AHMEDNAGAR         2007.0    1.0       0.0
# 5719  AHMEDNAGAR         2008.0    1.0       0.0
# 5720  AHMEDNAGAR         2009.0    1.0       0.0
# 5721  AHMEDNAGAR         2010.0    1.0       0.0
# 5722       AKOLA         2004.0    1.0      15.8
# 5723       AKOLA         2005.0    1.0      35.5
# 5724       AKOLA         2006.0    1.0       0.0
# 5725       AKOLA         2007.0    1.0       0.0
# 5726       AKOLA         2008.0    1.0      14.3
# 5727       AKOLA         2009.0    1.0       0.0
# 5728       AKOLA         2010.0    1.0      29.6
# 5729    AMRAVATI         2004.0    1.0      18.7
# 5730    AMRAVATI         2005.0    1.0      10.7
# 5731  AURANGABAD         2004.0    1.0       1.1
# 5732  AURANGABAD         2005.0    1.0       0.2
# ...

# %%
Base_rainfall_expanded.District.unique()
# Out:
# array(['AHMEDNAGAR', 'AKOLA', 'AMRAVATI', 'AURANGABAD', 'BEED',
#        'BHANDARA', 'BULDANA', 'CHANDRAPUR', 'DHULIE', 'GADCHIROLI',
#        'GONDIA', 'JALGAON', 'JALNA', 'KOLHAPUR', 'LATUR', 'MUMBAI',
#        'NAGPUR', 'NANDED', 'NANDURBAR', 'NASHIK', 'OSMANABAD', 'PARBHANI',
#        'PUNE', 'RAIGAD', 'RATNAGIRI', 'SANGLI', 'SATARA', 'SOLAPUR',
#        'SINDHUDURG', 'THANE', 'WARDHA', 'WASHIM', 'YEOTMAL'], dtype=object)

# %%
['AKOLA', 'AMRAVATI', 'AURANGABAD', 'BADLAPUR', 'CHANDRAPUR',
       'DOMBIVLI', 'GREATER MUMBAI', 'JALGAON', 'JALNA', 'KOLHAPUR',
       'LATUR', 'LOTE', 'MAHAD', 'MUMBAI', 'NAGPUR', 'NANDED', 'NASHIK',
       'NAVI MUMBAI', 'PUNE', 'ROHA', 'SANGLI', 'SOLAPUR', 'TARAPUR',
       'THANE', 'ULHASNAGAR']

# %%
(['AMRAVATI', 'AURANGABAD', 'CHANDRAPUR', 'JALGAON', 'KOLHAPUR',
       'LATUR', 'MUMBAI', 'NAGPUR', 'NASHIK', 'PUNE', 'SANGLI', 'SOLAPUR',
       'THANE']

# %%
'AKOLA','JALNA','NANDED',{'NASIK':'NASHIK','SHOLAPUR':'SOLAPUR'}

# %%
Base_polpop_iell_rf.loc[Base_polpop_iell_rf.City_Town_Village_Area.isnull() ,['District', 'Year_rainfall', 'month', 'rainfall']]
# Out:
#         District  Year_rainfall  month  rainfall
# 5715  AHMEDNAGAR         2004.0    1.0       0.0
# 5716  AHMEDNAGAR         2005.0    1.0       0.8
# 5717  AHMEDNAGAR         2006.0    1.0       0.0
# 5718  AHMEDNAGAR         2007.0    1.0       0.0
# 5719  AHMEDNAGAR         2008.0    1.0       0.0
# 5720  AHMEDNAGAR         2009.0    1.0       0.0
# 5721  AHMEDNAGAR         2010.0    1.0       0.0
# 5722       AKOLA         2004.0    1.0      15.8
# 5723       AKOLA         2005.0    1.0      35.5
# 5724       AKOLA         2006.0    1.0       0.0
# 5725       AKOLA         2007.0    1.0       0.0
# 5726       AKOLA         2008.0    1.0      14.3
# 5727       AKOLA         2009.0    1.0       0.0
# 5728       AKOLA         2010.0    1.0      29.6
# 5729    AMRAVATI         2004.0    1.0      18.7
# 5730    AMRAVATI         2005.0    1.0      10.7
# 5731  AURANGABAD         2004.0    1.0       1.1
# 5732  AURANGABAD         2005.0    1.0       0.2
# ...

# %%
Base_polpop_iell_cs.loc[Base_polpop_iell_cs.City_Town_Village_Area=='AKOLA','year_number'].unique()
# Out:
# array([2011, 2012, 2013, 2015, 2014], dtype=int64)

# %%
Base_polpop_iell_cs.loc[Base_polpop_iell_cs.City_Town_Village_Area=='AMRAVATI','year_number'].unique()
# Out:
# array([2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2015, 2014],
#       dtype=int64)

# %%
Base_polpop_iell_cs.loc[Base_polpop_iell_cs.City_Town_Village_Area=='AURANGABAD','year_number'].unique()
# Out:
# array([2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2005,
#        1994, 1993], dtype=int64)

# %%
Base_polpop_iell_cs.loc[Base_polpop_iell_cs.City_Town_Village_Area=='AKOLA']
# Out:
#      Unnamed: 0  Unnamed: 0.1 City_Town_Village_Area Type_of_Location  \
# 96           96            96               AMRAVATI       Industrial
# 97           97            97               AMRAVATI       Industrial
# 98           98            98               AMRAVATI       Industrial
# 99           99            99               AMRAVATI       Industrial
# 100         100           100               AMRAVATI       Industrial
# 101         101           101               AMRAVATI      Residential
# 102         102           102               AMRAVATI      Residential
# 103         103           103               AMRAVATI      Residential
# 104         104           104               AMRAVATI      Residential
# 105         105           105               AMRAVATI      Residential
# 106         106           106               AMRAVATI      Residential
# 107         107           107               AMRAVATI      Residential
# ...

# %%
Base_polpop_iell_rf.loc[Base_polpop_iell_rf.City_Town_Village_Area=='AMRAVATI']
# Out:
#      Unnamed: 0  Unnamed: 0.1 City_Town_Village_Area Type_of_Location  \
# 96         96.0          96.0               AMRAVATI       Industrial
# 97        101.0         101.0               AMRAVATI      Residential
# 98         97.0          97.0               AMRAVATI       Industrial
# 99         98.0          98.0               AMRAVATI       Industrial
# 100        99.0          99.0               AMRAVATI       Industrial
# 101       109.0         109.0               AMRAVATI      Residential
# 102       100.0         100.0               AMRAVATI       Industrial
# 103       110.0         110.0               AMRAVATI      Residential
# 104       102.0         102.0               AMRAVATI      Residential
# 105       103.0         103.0               AMRAVATI      Residential
# 106       104.0         104.0               AMRAVATI      Residential
# 107       105.0         105.0               AMRAVATI      Residential
# ...

# %%
Base_polpop_iell_rf.loc[(~Base_polpop_iell_rf.City_Town_Village_Area.isnull()) & (~Base_polpop_iell_rf.District.isnull()),['District', 'Year_rainfall', 'month', 'rainfall']]
# Out:
#       District  Year_rainfall  month  rainfall
# 96    AMRAVATI         2006.0    1.0       0.0
# 97    AMRAVATI         2006.0    1.0       0.0
# 98    AMRAVATI         2006.0    7.0     260.8
# 99    AMRAVATI         2006.0    8.0     327.6
# 100   AMRAVATI         2006.0   11.0       4.7
# 101   AMRAVATI         2006.0   11.0       4.7
# 102   AMRAVATI         2006.0   12.0       0.0
# 103   AMRAVATI         2006.0   12.0       0.0
# 104   AMRAVATI         2006.0    2.0       0.0
# 105   AMRAVATI         2006.0    3.0     118.8
# 106   AMRAVATI         2006.0    4.0      23.4
# 107   AMRAVATI         2006.0    5.0      23.0
# 108   AMRAVATI         2006.0    6.0      66.7
# 109   AMRAVATI         2006.0    9.0     138.1
# 110   AMRAVATI         2006.0   10.0      43.9
# 111   AMRAVATI         2007.0    1.0       0.0
# 112   AMRAVATI         2007.0    1.0       0.0
# 113   AMRAVATI         2007.0    2.0       4.2
# 114   AMRAVATI         2007.0    2.0       4.2
# ...

# %%
Base_polpop_iell_rf.loc[(~Base_polpop_iell_rf.City_Town_Village_Area.isnull()) & (~Base_polpop_iell_rf.District.isnull()),'District'].unique()
# Out:
# array(['AMRAVATI', 'AURANGABAD', 'CHANDRAPUR', 'JALGAON', 'KOLHAPUR',
#        'LATUR', 'MUMBAI', 'NAGPUR', 'NASHIK', 'PUNE', 'SANGLI', 'SOLAPUR',
#        'THANE'], dtype=object)

# %%
Base_polpop_iell_rf=Base_polpop_iell_cs.merge(Base_rainfall_expanded,how='left', suffixes=('_ppiellsc', '_rainfall'),left_on=['City_Town_Village_Area','year_number','month_number'], right_on=['District','Year','month'])

# %%
Base_polpop_iell_rf.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'City_Town_Village_Area',
#        'Type_of_Location', 'TS', 'year_number', 'month_number', 'NO2_Median',
#        'RSPM_PM10_Median', 'SO2_Median', 'SPM_Median', 'Median_SO2_MOM_diff',
#        'Median_NO2_MOM_diff', 'Median_RSPM_PM10_MOM_diff',
#        'Median_SPM_MOM_diff', 'NO2_P10', 'RSPM_PM10_P10', 'SO2_P10', 'SPM_P10',
#        'P10_NO2_MOM_diff', 'P10_SO2_MOM_diff', 'P10_RSPM_PM10_MOM_diff',
#        'P10_SPM_MOM_diff', 'NO2_P90', 'RSPM_PM10_P90', 'SO2_P90', 'SPM_P90',
#        'month_number_diff', 'P90_NO2_MOM_diff', 'P90_SO2_MOM_diff',
#        'P90_RSPM_PM10_MOM_diff', 'P90_SPM_MOM_diff', 'year_number_diff',
#        'NO2_Median_YOY_diff', 'SO2_Median_YOY_diff',
#        'RSPM_PM10_Median_YOY_diff', 'SPM_Median_YOY_diff', 'NO2_P10_YOY_diff',
#        'SO2_P10_YOY_diff', 'RSPM_PM10_P10_YOY_diff', 'SPM_P10_YOY_diff',
#        'NO2_P90_YOY_diff', 'SO2_P90_YOY_diff', 'RSPM_PM10_P90_YOY_diff',
# ...

# %%
Base_polpop_iell_rf.to_csv(path_or_buf ='C:\MS\EDA\Base_polpop_iell_csrf_16oct.csv')

# %%
NO2COL=['City_Town_Village_Area','Type_of_Location','month_number','NO2_Median','Median_NO2_MOM_diff','NO2_P10','P10_NO2_MOM_diff','NO2_P90','P90_NO2_MOM_diff','NO2_Median_YOY_diff','NO2_P10_YOY_diff','NO2_P90_YOY_diff','rainfall']

SO2COL=['City_Town_Village_Area','Type_of_Location','month_number','SO2_Median','Median_SO2_MOM_diff','SO2_P10','P10_SO2_MOM_diff','SO2_P90','P90_SO2_MOM_diff','SO2_Median_YOY_diff','SO2_P10_YOY_diff','SO2_P90_YOY_diff','rainfall']

RSPMPM10COL=['City_Town_Village_Area','Type_of_Location','month_number','RSPM_PM10_Median','Median_RSPM_PM10_MOM_diff','RSPM_PM10_P10','P10_RSPM_PM10_MOM_diff','RSPM_PM10_P90','P90_RSPM_PM10_MOM_diff','RSPM_PM10_Median_YOY_diff','RSPM_PM10_P10_YOY_diff','RSPM_PM10_P90_YOY_diff','rainfall']

# %%
corrmat = Base_polpop_iell_rf[NO2COL].corr() 
  
f, ax = plt.subplots(figsize =(16, 8)) 
sns.heatmap(corrmat, ax = ax, cmap ="YlGnBu", linewidths = 0.1)

# %%
corrmat = Base_polpop_iell_rf[NO2COL].corr() 
  
cg = sns.clustermap(corrmat, cmap ="YlGnBu", linewidths = 0.1); 
plt.setp(cg.ax_heatmap.yaxis.get_majorticklabels(), rotation = 0) 
  
cg

# %%
corrmat = Base_polpop_iell_rf[SO2COL].corr() 
  
f, ax = plt.subplots(figsize =(16, 8)) 
sns.heatmap(corrmat, ax = ax, cmap ="YlGnBu", linewidths = 0.1)

# %%
corrmat = Base_polpop_iell_rf[SO2COL].corr() 
  
cg = sns.clustermap(corrmat, cmap ="YlGnBu", linewidths = 0.1); 
plt.setp(cg.ax_heatmap.yaxis.get_majorticklabels(), rotation = 0) 
  
cg

# %%
corrmat = Base_polpop_iell_rf[RSPMPM10COL].corr() 
  
f, ax = plt.subplots(figsize =(16, 8)) 
sns.heatmap(corrmat, ax = ax, cmap ="YlGnBu", linewidths = 0.1)

# %%
corrmat = Base_polpop_iell_rf[RSPMPM10COL].corr() 
  
cg = sns.clustermap(corrmat, cmap ="YlGnBu", linewidths = 0.1); 
plt.setp(cg.ax_heatmap.yaxis.get_majorticklabels(), rotation = 0) 
  
cg
