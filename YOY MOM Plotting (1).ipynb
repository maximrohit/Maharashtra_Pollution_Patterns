# %%
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Base_Poll_MOM = pd.read_csv("D:\personal\MS\EDA\YOY_P105090_all.csv")

# %%
Base_Poll_MOM.columns
# Out:
# Index(['Unnamed: 0', 'City_Town_Village_Area', 'Type_of_Location', 'TS',
#        'year_number', 'month_number', 'NO2_Median', 'RSPM_PM10_Median',
#        'SO2_Median', 'SPM_Median', 'Median_SO2_MOM_diff',
#        'Median_NO2_MOM_diff', 'Median_RSPM_PM10_MOM_diff',
#        'Median_SPM_MOM_diff', 'NO2_P10', 'RSPM_PM10_P10', 'SO2_P10', 'SPM_P10',
#        'P10_NO2_MOM_diff', 'P10_SO2_MOM_diff', 'P10_RSPM_PM10_MOM_diff',
#        'P10_SPM_MOM_diff', 'NO2_P90', 'RSPM_PM10_P90', 'SO2_P90', 'SPM_P90',
#        'month_number_diff', 'P90_NO2_MOM_diff', 'P90_SO2_MOM_diff',
#        'P90_RSPM_PM10_MOM_diff', 'P90_SPM_MOM_diff', 'year_number_diff',
#        'NO2_Median_YOY_diff', 'SO2_Median_YOY_diff',
#        'RSPM_PM10_Median_YOY_diff', 'SPM_Median_YOY_diff', 'NO2_P10_YOY_diff',
#        'SO2_P10_YOY_diff', 'RSPM_PM10_P10_YOY_diff', 'SPM_P10_YOY_diff',
#        'NO2_P90_YOY_diff', 'SO2_P90_YOY_diff', 'RSPM_PM10_P90_YOY_diff',
#        'SPM_P90_YOY_diff'],
#       dtype='object')

# %%
plt.figure(figsize = (15,8))
plt.subplot(3,1,1)
plt.xticks(np.arange(min(Base_Poll_MOM.year_number), max(Base_Poll_MOM.year_number)+1, 1.0),rotation=90)
sns.lineplot(x="year_number", y="SO2_P10",hue='City_Town_Village_Area',  data=Base_Poll_MOM)
plt.legend( bbox_to_anchor=(0.0, 0.0),loc=0, ncol=3)
plt.subplot(3,1,2)
plt.xticks(np.arange(min(Base_Poll_MOM.year_number), max(Base_Poll_MOM.year_number)+1, 1.0),rotation=90)
sns.lineplot(x="year_number", y="SO2_P90",hue='City_Town_Village_Area',legend=False,  data=Base_Poll_MOM)
#plt.legend( bbox_to_anchor=(0.0, 0.0),loc=0, ncol=3)
plt.subplot(3,1,3)
plt.xticks(np.arange(min(Base_Poll_MOM.year_number), max(Base_Poll_MOM.year_number)+1, 1.0),rotation=90)
sns.lineplot(x="year_number", y="SO2_Median",hue='City_Town_Village_Area',legend=False,  data=Base_Poll_MOM)
#plt.legend( bbox_to_anchor=(0.0, 0.0),loc=0, ncol=3)

##teh data is moving in range no abnormality atleast vsually

# %%
plt.figure(figsize = (15,8))
plt.subplot(3,1,1)
plt.xticks(np.arange(min(Base_Poll_MOM.year_number), max(Base_Poll_MOM.year_number)+1, 1.0),rotation=90)
sns.lineplot(x="year_number", y="Median_SO2_MOM_diff",hue='City_Town_Village_Area',  data=Base_Poll_MOM)
plt.legend( bbox_to_anchor=(0.0, 0.0),loc=0, ncol=3)
plt.subplot(3,1,2)
plt.xticks(np.arange(min(Base_Poll_MOM.year_number), max(Base_Poll_MOM.year_number)+1, 1.0),rotation=90)
sns.lineplot(x="year_number", y="P10_SO2_MOM_diff",hue='City_Town_Village_Area',legend=False,  data=Base_Poll_MOM)
#plt.legend( bbox_to_anchor=(0.0, 0.0),loc=0, ncol=3)
plt.subplot(3,1,3)
plt.xticks(np.arange(min(Base_Poll_MOM.year_number), max(Base_Poll_MOM.year_number)+1, 1.0),rotation=90)
sns.lineplot(x="year_number", y="P90_SO2_MOM_diff",hue='City_Town_Village_Area',legend=False,  data=Base_Poll_MOM)
#plt.legend( bbox_to_anchor=(0.0, 0.0),loc=0, ncol=3)
##as previously noted MOM diff in so2 is not that imp

# %%
plt.figure(figsize = (15,8))
plt.subplot(3,1,1)
plt.xticks(np.arange(min(Base_Poll_MOM.year_number), max(Base_Poll_MOM.year_number)+1, 1.0),rotation=90)
sns.lineplot(x="year_number", y="SO2_Median_YOY_diff",hue='City_Town_Village_Area',  data=Base_Poll_MOM)
plt.legend( bbox_to_anchor=(0.0, 0.0),loc=0, ncol=3)
plt.subplot(3,1,2)
plt.xticks(np.arange(min(Base_Poll_MOM.year_number), max(Base_Poll_MOM.year_number)+1, 1.0),rotation=90)
sns.lineplot(x="year_number", y="SO2_P10_YOY_diff",hue='City_Town_Village_Area',legend=False,  data=Base_Poll_MOM)
#plt.legend( bbox_to_anchor=(0.0, 0.0),loc=0, ncol=3)
plt.subplot(3,1,3)
plt.xticks(np.arange(min(Base_Poll_MOM.year_number), max(Base_Poll_MOM.year_number)+1, 1.0),rotation=90)
sns.lineplot(x="year_number", y="SO2_P90_YOY_diff",hue='City_Town_Village_Area',legend=False,  data=Base_Poll_MOM)
#plt.legend( bbox_to_anchor=(0.0, 0.0),loc=0, ncol=3)
##as previously noted YOY diff in so2 is  imp

# %%
plt.figure(figsize = (15,8))
plt.subplot(3,1,1)
plt.xticks(np.arange(min(Base_Poll_MOM.year_number), max(Base_Poll_MOM.year_number)+1, 1.0),rotation=90)
sns.lineplot(x="year_number", y="NO2_Median_YOY_diff",hue='City_Town_Village_Area',  data=Base_Poll_MOM)
plt.legend( bbox_to_anchor=(0.0, 0.0),loc=0, ncol=3)
plt.subplot(3,1,2)
plt.xticks(np.arange(min(Base_Poll_MOM.year_number), max(Base_Poll_MOM.year_number)+1, 1.0),rotation=90)
sns.lineplot(x="year_number", y="NO2_P10_YOY_diff",hue='City_Town_Village_Area',legend=False,  data=Base_Poll_MOM)
#plt.legend( bbox_to_anchor=(0.0, 0.0),loc=0, ncol=3)
plt.subplot(3,1,3)
plt.xticks(np.arange(min(Base_Poll_MOM.year_number), max(Base_Poll_MOM.year_number)+1, 1.0),rotation=90)
sns.lineplot(x="year_number", y="NO2_P90_YOY_diff",hue='City_Town_Village_Area',legend=False,  data=Base_Poll_MOM)
#plt.legend( bbox_to_anchor=(0.0, 0.0),loc=0, ncol=3)
##as previously noted YOY diff in NO2 is imp

# %%
plt.figure(figsize = (15,8))
plt.subplot(3,1,1)
plt.xticks(np.arange(min(Base_Poll_MOM.year_number), max(Base_Poll_MOM.year_number)+1, 1.0),rotation=90)
sns.lineplot(x="year_number", y="Median_NO2_MOM_diff",hue='City_Town_Village_Area',  data=Base_Poll_MOM)
plt.legend( bbox_to_anchor=(0.0, 0.0),loc=0, ncol=3)
plt.subplot(3,1,2)
plt.xticks(np.arange(min(Base_Poll_MOM.year_number), max(Base_Poll_MOM.year_number)+1, 1.0),rotation=90)
sns.lineplot(x="year_number", y="P10_NO2_MOM_diff",hue='City_Town_Village_Area',legend=False,  data=Base_Poll_MOM)
#plt.legend( bbox_to_anchor=(0.0, 0.0),loc=0, ncol=3)
plt.subplot(3,1,3)
plt.xticks(np.arange(min(Base_Poll_MOM.year_number), max(Base_Poll_MOM.year_number)+1, 1.0),rotation=90)
sns.lineplot(x="year_number", y="P90_NO2_MOM_diff",hue='City_Town_Village_Area',legend=False,  data=Base_Poll_MOM)
#plt.legend( bbox_to_anchor=(0.0, 0.0),loc=0, ncol=3)
## MOM diff in NO2 is mor imp in term of median and 90 percentile as compared to 10 percentile

# %%
plt.figure(figsize = (15,8))
plt.subplot(3,1,1)
plt.xticks(np.arange(min(Base_Poll_MOM.year_number), max(Base_Poll_MOM.year_number)+1, 1.0),rotation=90)
sns.lineplot(x="year_number", y="P10_RSPM_PM10_MOM_diff",hue='City_Town_Village_Area',  data=Base_Poll_MOM)
plt.legend( bbox_to_anchor=(0.0, 0.0),loc=0, ncol=3)
plt.subplot(3,1,2)
plt.xticks(np.arange(min(Base_Poll_MOM.year_number), max(Base_Poll_MOM.year_number)+1, 1.0),rotation=90)
sns.lineplot(x="year_number", y="Median_RSPM_PM10_MOM_diff",hue='City_Town_Village_Area',legend=False,  data=Base_Poll_MOM)
#plt.legend( bbox_to_anchor=(0.0, 0.0),loc=0, ncol=3)
plt.subplot(3,1,3)
plt.xticks(np.arange(min(Base_Poll_MOM.year_number), max(Base_Poll_MOM.year_number)+1, 1.0),rotation=90)
sns.lineplot(x="year_number", y="P90_RSPM_PM10_MOM_diff",hue='City_Town_Village_Area',legend=False,  data=Base_Poll_MOM)
#plt.legend( bbox_to_anchor=(0.0, 0.0),loc=0, ncol=3)
##MOM not that imp for RSPM_PM10

# %%
plt.figure(figsize = (15,8))
plt.subplot(3,1,1)
plt.xticks(np.arange(min(Base_Poll_MOM.year_number), max(Base_Poll_MOM.year_number)+1, 1.0),rotation=90)
sns.lineplot(x="year_number", y="RSPM_PM10_P10_YOY_diff",hue='City_Town_Village_Area',  data=Base_Poll_MOM)
plt.legend( bbox_to_anchor=(0.0, 0.0),loc=0, ncol=3)
plt.subplot(3,1,2)
plt.xticks(np.arange(min(Base_Poll_MOM.year_number), max(Base_Poll_MOM.year_number)+1, 1.0),rotation=90)
sns.lineplot(x="year_number", y="RSPM_PM10_Median_YOY_diff",hue='City_Town_Village_Area',legend=False,  data=Base_Poll_MOM)
#plt.legend( bbox_to_anchor=(0.0, 0.0),loc=0, ncol=3)
plt.subplot(3,1,3)
plt.xticks(np.arange(min(Base_Poll_MOM.year_number), max(Base_Poll_MOM.year_number)+1, 1.0),rotation=90)
sns.lineplot(x="year_number", y="RSPM_PM10_P90_YOY_diff",hue='City_Town_Village_Area',legend=False,  data=Base_Poll_MOM)
#plt.legend( bbox_to_anchor=(0.0, 0.0),loc=0, ncol=3)
##yoy is imp for RSPM_PM10

# %%
plt.figure(figsize = (15,8))
plt.subplot(3,1,1)
plt.xticks(np.arange(min(Base_Poll_MOM.year_number), max(Base_Poll_MOM.year_number)+1, 1.0),rotation=90)
sns.lineplot(x="year_number", y="SPM_P10_YOY_diff",hue='City_Town_Village_Area',  data=Base_Poll_MOM)
plt.legend( bbox_to_anchor=(0.0, 0.0),loc=0, ncol=3)
plt.subplot(3,1,2)
plt.xticks(np.arange(min(Base_Poll_MOM.year_number), max(Base_Poll_MOM.year_number)+1, 1.0),rotation=90)
sns.lineplot(x="year_number", y="SPM_Median_YOY_diff",hue='City_Town_Village_Area',legend=False,  data=Base_Poll_MOM)
#plt.legend( bbox_to_anchor=(0.0, 0.0),loc=0, ncol=3)
plt.subplot(3,1,3)
plt.xticks(np.arange(min(Base_Poll_MOM.year_number), max(Base_Poll_MOM.year_number)+1, 1.0),rotation=90)
sns.lineplot(x="year_number", y="SPM_P90_YOY_diff",hue='City_Town_Village_Area',legend=False,  data=Base_Poll_MOM)
#plt.legend( bbox_to_anchor=(0.0, 0.0),loc=0, ncol=3)
#p90 is more erratic but agan yoy for spm is imp

# %%
plt.figure(figsize = (15,8))
plt.subplot(3,1,1)
plt.xticks(np.arange(min(Base_Poll_MOM.year_number), max(Base_Poll_MOM.year_number)+1, 1.0),rotation=90)
sns.lineplot(x="year_number", y="P10_SPM_MOM_diff",hue='City_Town_Village_Area',  data=Base_Poll_MOM)
plt.legend( bbox_to_anchor=(0.0, 0.0),loc=0, ncol=3)
plt.subplot(3,1,2)
plt.xticks(np.arange(min(Base_Poll_MOM.year_number), max(Base_Poll_MOM.year_number)+1, 1.0),rotation=90)
sns.lineplot(x="year_number", y="Median_SPM_MOM_diff",hue='City_Town_Village_Area',legend=False,  data=Base_Poll_MOM)
#plt.legend( bbox_to_anchor=(0.0, 0.0),loc=0, ncol=3)
plt.subplot(3,1,3)
plt.xticks(np.arange(min(Base_Poll_MOM.year_number), max(Base_Poll_MOM.year_number)+1, 1.0),rotation=90)
sns.lineplot(x="year_number", y="P90_SPM_MOM_diff",hue='City_Town_Village_Area',legend=False,  data=Base_Poll_MOM)
#plt.legend( bbox_to_anchor=(0.0, 0.0),loc=0, ncol=3)
#mom is imp for spm it seems

# %%
Base_Poll_MOM.columns
# Out:
# Index(['Unnamed: 0', 'City_Town_Village_Area', 'Type_of_Location', 'TS',
#        'year_number', 'month_number', 'NO2_Median', 'RSPM_PM10_Median',
#        'SO2_Median', 'SPM_Median', 'Median_SO2_MOM_diff',
#        'Median_NO2_MOM_diff', 'Median_RSPM_PM10_MOM_diff',
#        'Median_SPM_MOM_diff', 'NO2_P10', 'RSPM_PM10_P10', 'SO2_P10', 'SPM_P10',
#        'P10_NO2_MOM_diff', 'P10_SO2_MOM_diff', 'P10_RSPM_PM10_MOM_diff',
#        'P10_SPM_MOM_diff', 'NO2_P90', 'RSPM_PM10_P90', 'SO2_P90', 'SPM_P90',
#        'month_number_diff', 'P90_NO2_MOM_diff', 'P90_SO2_MOM_diff',
#        'P90_RSPM_PM10_MOM_diff', 'P90_SPM_MOM_diff', 'year_number_diff',
#        'NO2_Median_YOY_diff', 'SO2_Median_YOY_diff',
#        'RSPM_PM10_Median_YOY_diff', 'SPM_Median_YOY_diff', 'NO2_P10_YOY_diff',
#        'SO2_P10_YOY_diff', 'RSPM_PM10_P10_YOY_diff', 'SPM_P10_YOY_diff',
#        'NO2_P90_YOY_diff', 'SO2_P90_YOY_diff', 'RSPM_PM10_P90_YOY_diff',
#        'SPM_P90_YOY_diff'],
#       dtype='object')

# %%
plt.figure(figsize = (15,8))
plt.subplot(1,3,1)
plt.xticks(np.arange(min(Base_Poll_MOM.year_number), max(Base_Poll_MOM.year_number)+1, 1.0),rotation=90)
sns.lineplot(x="year_number", y="SO2_P10_YOY_diff", data=Base_Poll_MOM)
plt.subplot(1,3,2)
plt.xticks(np.arange(min(Base_Poll_MOM.year_number), max(Base_Poll_MOM.year_number)+1, 1.0),rotation=90)
sns.lineplot(x="year_number", y="SO2_Median_YOY_diff", data=Base_Poll_MOM)
plt.subplot(1,3,3)
plt.xticks(np.arange(min(Base_Poll_MOM.year_number), max(Base_Poll_MOM.year_number)+1, 1.0),rotation=90)
sns.lineplot(x="year_number", y="SO2_P90_YOY_diff", data=Base_Poll_MOM)
